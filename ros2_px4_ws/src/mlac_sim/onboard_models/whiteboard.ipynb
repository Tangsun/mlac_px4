# %%
import pickle

# %%
# load the model "models/pnorm_models/run_3_lambda_0 blabla"
model_path = "../models/pnorm_models/run_3_lambda_0.008_k_0.004_pfreq_20_pnorm_2.0/E=1000_pinit=2.00_pfreq=20_regP=1.0000_regL=0.0080_regK=0.0040_zw=1.50_regkR=0.0001.pkl"

def load_model(model_path):
    with open(model_path, 'rb') as f:
        model = pickle.load(f)
    return model

# %%
model = load_model(model_path)

# %%
model.keys()
# Out:
# dict_keys(['best_step_meta', 'best_step_pnorm', 'hparams', 'ensemble', 'model', 'controller', 'pnorm', 'regP', 'train_lossaux_history', 'valid_loss_history', 'pnorm_history', 'ensemble_loss', 't_knots', 'coefs', 'min_ref', 'max_ref'])
